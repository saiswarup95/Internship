# %%
# !pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Q1. Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Analyst” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
driver.find_element(By.XPATH,'//button[@class="btn-close "]').click()

# %%
driver.find_element(By.XPATH,'//input[@class="input"]').click()

# %%
designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys("Data Analyst")

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button')
search.click()

# %%
job_title=[]
job_location=[]
job_company=[]
job_experience=[]

title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    job_company.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    job_experience.append(exp)

# %%
print(len(job_title),len(job_location),len(job_company),len(job_experience))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title ':job_title,'Location':job_location,'Company':job_company,'Experience':job_experience})
df
# Out:
#                                               Title        Location  \
# 0                             Technical Data Analyst  Bangalore\n+9
# 1                    opening data analyst -Bangalore      Bangalore
# 2  Data Entry Operator(data analyst work) REMOTE ...  Bangalore\n+9
# 3                            Hiring For Data Analyst  Bangalore\n+8
# 4                                Senior Data Analyst  Bangalore\n+8
# 5                                       Data Analyst      Bangalore
# 6                     Mobility Data Analyst - IN/MKR      Bangalore
# 7                                Senior Data Analyst      Bangalore
# 8  hiring for data entry analyst ( position data ...  Bangalore\n+9
# 9  hiring for data entry analyst ( position data ...  Bangalore\n+9
#
#                                   Company  Experience
# 0  krishna consultancy.. hiring for co...  4 to 9 Yrs
# 1          provizor it services pvt. ltd.  2 to 5 Yrs
# 2                        prime services..   0 to 1 Yr
# ...

# %% [markdown]
# Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Scientist” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
driver.find_element(By.XPATH,'//button[@class="btn-close "]').click()

# %%
driver.find_element(By.XPATH,'//input[@class="input"]').click()

# %%
designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys("Data Scientist")

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button')
search.click()

# %%
job_title=[]
job_location=[]
job_company=[]

title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    job_company.append(company)

# %%
print(len(job_title),len(job_location),len(job_company))
# Out:
# 10 10 10

# %%
df=pd.DataFrame({'Title ':job_title,'Location':job_location,'Company':job_company})
df
# Out:
#                                               Title         Location  \
# 0                                     Data Scientist       Bangalore
# 1                                 SR. DATA SCIENTIST       Bangalore
# 2                 Senior Data Scientist- ML Engineer       Bangalore
# 3                                 Data Scientist III       Bangalore
# 4       Data Scientist Hiring Fresher and Experience  Bangalore\n+17
# 5  Opening for Computer executive, data typing , ...   Bangalore\n+9
# 6                                     Data Scientist   Bangalore\n+6
# 7                         Senior Data Scientist, AWS       Bangalore
# 8                         Data Scientist Recruitment  Bangalore\n+17
# 9  Data Engineer II, Amazon WFM Tech Enterprise Data       Bangalore
#
#                          Company
# 0              the fashion cosmo
# 1  te connectivity india pvt ltd
# 2              sap india pvt ltd
# 3                         inmobi
# 4       kavya staffing solutions
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
#
# The task will be done as shown in the below steps:
# 1. first get the web page https://www.shine.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
driver.find_element(By.XPATH,'//button[@class="btn-close "]').click()

# %%
driver.find_element(By.XPATH,'//input[@class="input"]').click()

# %%
designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys("Data Scientist")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button')
search.click()

# %%
driver.find_element(By.XPATH,'//button[@class="filter_filterBtn__FAqUy btn btn-outline-grey font-size-xs link-color"]').click()

# %%
driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/ul/li[8]/span').click()

# %%
driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/ul/li[3]').click()

# %%
driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/ul/li[3]/span').click()

# %%
driver.find_element(By.XPATH,'//*[@id="__next"]/div[1]/div[4]/div/div[1]/div/div[2]/div[2]/div/div/div/div[4]/button[2]').click()

# %%
job_title=[]
job_location=[]
job_company=[]
job_experience=[]

title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags[0:10]:
    company=i.text
    job_company.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags[0:10]:
    exp=i.text
    job_experience.append(exp)

# %%
print(len(job_title),len(job_location),len(job_company),len(job_experience))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Title ':job_title,'Location':job_location,'Company':job_company,'Experience':job_experience})
df
# Out:
#                                    Title    Location  \
# 0                          Data Scientist  Delhi\n+6
# 1                    DATA SCIENTIST DELHI      Delhi
# 2                          Data Scientist  Delhi\n+6
# 3              Apply for Data Entry Delhi      Delhi
# 4                     Data Entry Operator  Delhi\n+9
# 5                  Technical Data Analyst  Delhi\n+9
# 6                        DATA ENTRY DELHI      Delhi
# 7                      Require Data Entry      Delhi
# 8  Urgent requirement Data Entry Operator  Delhi\n+9
# 9    GIS-Utility Network Model Consultant  Delhi\n+8
#
#                                   Company   Experience
# 0                         quiscon biotech    0 to 1 Yr
# 1                     skyleaf consultants   3 to 6 Yrs
# 2                         quiscon biotech   0 to 3 Yrs
# 3                          rise placement   0 to 3 Yrs
# 4  apex trading & softech solutions hi...    0 to 1 Yr
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 6. Brand
# 7. Product Description
# 8. Price
#
# To scrape the data you have to go through following steps:
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual.
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then click on it.
# 5. Now scrape data from this page as usual
# 6. Repeat this until you get data for 100sunglasses.
# Note: That all of the above steps have to be done by coding only and not manually.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
pop_up = driver.find_element(By.XPATH,"/html/body/div[3]/div/span")
pop_up.click()

# %%
driver.find_element(By.XPATH,'//input[@class="Pke_EE"]').send_keys('sunglasses')

# %%
driver.find_element(By.XPATH,'//button[@class="_2iLD__"]').click()

# %%
brand=[]
product_description=[]
price=[]


for page in range(0,3):
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brandName=i.text
        brand.append(brandName)
    
    product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags[0:100]:
        productD=i.text
        product_description.append(productD)
        
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price_t=i.text
        price.append(price_t)

# %%
next_page=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_page.click
time.sleep(3)

# %%
df=pd.DataFrame({'Brand':brand[0:100],'Product Description':product_description[0:100],'Price':price[0:100]})
df
# Out:
#              Brand                                Product Description   Price
# 0    VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)    ₹549
# 1    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)    ₹849
# 2         Fastrack   UV Protection Rectangular Sunglasses (Free Size)    ₹499
# 3         Fastrack              UV Protection Aviator Sunglasses (58)    ₹799
# 4         Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...    ₹549
# ..             ...                                                ...     ...
# 95        Fastrack  UV Protection Wayfarer, Sports, Spectacle , Re...    ₹849
# 96  ROZZETTA CRAFT    UV Protection Wayfarer, Aviator Sunglasses (50)    ₹424
# 97     Eyewearlabs        UV Protection Sports Sunglasses (Free Size)  ₹1,236
# 98       90stethix  by Lenskart UV Protection Clubmaster Sunglasse...    ₹299
# 99          PIRASO  UV Protection Retro Square Sunglasses (Free Size)    ₹279
#
# [100 rows x 3 columns]

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-white-64-gb/product-reviews/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XE9ADHVW&marketplace=FLIPKART
#
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100reviews.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-white-64-gb/product-reviews/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XE9ADHVW&marketplace=FLIPKART")

# %%
rating=[]
review_summary=[]
full_review=[]


start=0
end=10

for page in range(start,end):
    
    rating_tag=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tag[0:100]:
        rating_all=i.text
        rating.append(rating_all)
    
    summary_rs=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in summary_rs[0:100]:
        summary_review=i.text
        review_summary.append(summary_review)
    
    review_full=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]/div/div')
    for i in review_full[0:100]:
        review_fullAll=i.text
        full_review.append(review_fullAll)

# %%
next_page=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]/span')
next_page.click
time.sleep(3)

# %%
df=pd.DataFrame({'Rating':rating,'Review summary':review_summary,'Full review':full_review})
df
# Out:
#    Rating       Review summary  \
# 0       5  Best in the market!
# 1       5            Wonderful
# 2       5    Worth every penny
# 3       5            Must buy!
# 4       5       Classy product
# ..    ...                  ...
# 95      5             Terrific
# 96      5            Fabulous!
# 97      5            Just wow!
# 98      5       Classy product
# 99      5            Must buy!
#
#                                           Full review
# 0                                         Good Camera
# 1                              This is amazing at all
# 2   Feeling awesome after getting the delivery of ...
# 3   Go for iPhone 11 , if confused between iPhone ...
# 4   Camera is awesome\nBest battery backup\nA perf...
# ..                                                ...
# 95                                     Very very good
# 96                    Super🔥 and good performance 👌❤️
# 97                                  Perfect Product!!
# ...

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
#
# As shown in the below image, you have to scrape the above attributes.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
pop_up = driver.find_element(By.XPATH,"/html/body/div[3]/div/span")
pop_up.click()

# %%
driver.find_element(By.XPATH,'//input[@class="Pke_EE"]').send_keys('sneakers')

# %%
driver.find_element(By.XPATH,'//button[@class="_2iLD__"]').click()

# %%
brand=[]
product_description=[]
price=[]

time.sleep(3)

for page in range(0,3):
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand_tags[0:100]:
        brandName=i.text
        brand.append(brandName)
    
    product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in product_tags[0:100]:
        productD=i.text
        product_description.append(productD)
        
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags[0:100]:
        price_t=i.text
        price.append(price_t)

# %%
next_page=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_page.click
time.sleep(3)

# %%
df=pd.DataFrame({'Brand':brand[0:100],'Product Description':product_description[0:100],'Price':price[0:100]})
df
# Out:
#                     Brand                                Product Description  \
# 0                    aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 1                HOTSTYLE                                   Sneakers For Men
# 2                   asian                                   Sneakers For Men
# 3                   asian                                   Sneakers For Men
# 4         U.S. POLO ASSN.                           CLARKIN Sneakers For Men
# ..                    ...                                                ...
# 95  HRX by Hrithik Roshan               Spring Edge Alpha 1 Sneakers For Men
# 96               RapidBox                                   Sneakers For Men
# 97                 Kraasa                                   Sneakers For Men
# 98                 BIZDOM                                   Sneakers For Men
# 99                  asian                     Casual Shoe Sneakers For Women
#
#      Price
# 0     ₹279
# 1     ₹398
# ...

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:
#
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.amazon.in/")

# %%
driver.find_element(By.XPATH,'//*[@id="twotabsearchtextbox"]').send_keys('laptop')

# %%
driver.find_element(By.ID,'nav-search-submit-button').click()

# %%
CPU_M=driver.find_element(By.XPATH,'//*[@id="p_n_feature_twenty-three_browse-bin/27387168031"]/span/a/span')
CPU_M.click()

# %%
CPU_T=driver.find_element(By.XPATH,'//*[@id="p_n_feature_thirteen_browse-bin/12598163031"]/span/a/span')
CPU_T.click()

# %%
product_title=[]
product_rating=[]
product_price=[]

title_tags=driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in title_tags[0:10]:
    product_title.append(i.text)
    
product_tags=driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]/span[1]')
for i in product_tags[0:10]:
    rating=i.get_attribute('aria-label')
    product_rating.append(rating)
    
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price_tags[0:10]:
    product_price.append(i.text)

# %%
df=pd.DataFrame({'Title':product_title,'Rating':product_rating,'Price':product_price})
df
# Out:
#                                                Title              Rating  \
# 0  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...  4.3 out of 5 stars
# 1  Dell Inspiron 5430 Laptop, Intel Core i7-1360P...  3.3 out of 5 stars
# 2  ASUS Vivobook 15, Intel Core i7-12650H 12th Ge...  4.0 out of 5 stars
# 3  ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...  4.1 out of 5 stars
# 4  MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...  4.3 out of 5 stars
# 5  HP Victus Gaming Laptop, 12th Gen Intel Core i...  5.0 out of 5 stars
# 6  Acer Nitro 5 12th Gen Intel Core i7-12650H Gam...  4.1 out of 5 stars
# 7  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...  3.5 out of 5 stars
# 8  MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...  4.4 out of 5 stars
# 9  ASUS Creator Series Vivobook 14X OLED (2023), ...  4.5 out of 5 stars
#
#     Price
# 0  66,990
# 1  86,490
# 2  64,990
# 3  80,990
# 4  68,829
# 5  84,990
# 6  99,990
# 7  68,990
# 8  54,990
# 9  89,990

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.azquotes.com/")

# %%
driver.find_element(By.XPATH,'//*[@id="menu"]/div/div[3]/ul/li[5]/a').click()

# %%
quote=[]
author=[]
quotetype=[]


for page in range(0,10):
    Quote_tags=driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in Quote_tags[0:1000]:
        quote.append(i.text)
    
    Author_tags=driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in Author_tags[0:1000]:
        author.append(i.text)
        
    TypeQuotes_tags=driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in TypeQuotes_tags[0:1000]:
        quotetype.append(i.text)

# %%
next_page=driver.find_element(By.XPATH,'//*[@id="content"]/div/div[1]/div/div[4]/li[12]/a')
next_page.click
time.sleep(3)

# %%
print(len(quote),len(author),len(quotetype))
# Out:
# 1000 1000 1000

# %%
df=pd.DataFrame({'Quotes':quote,'Author':author,'Type Of Quotes':quotetype})
df
# Out:
#                                                 Quotes                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.motor1.com/")

# %%
driver.find_element(By.XPATH,'//input[@class="m1-search-panel-input m1-search-form-text"]').send_keys('50 most expensive cars')

# %%
driver.find_element(By.XPATH,'//button[@class="m1-search-panel-button m1-search-form-button-animate icon-search-svg"]').click()

# %%
driver.find_element(By.XPATH,'//*[@id="page_index_articles_search"]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a').click()

# %%
carname=[]
price=[]


Name_tags=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in Name_tags[0:50]:
    carname.append(i.text)
    
Price_tags=driver.find_elements(By.XPATH,'//div[@class="apInarticleSmallRes"]')
for i in Price_tags[0:50]:
    price.append(i.text)

# %%
df=pd.DataFrame({'Car Name':carname,'Prices':price})
df

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.jagranjosh.com/")

# %%
driver.find_element(By.XPATH,'//*[@id="__next"]/header/nav/div/div/div[3]/ul/li[3]/a').click()

# %%
driver.find_element(By.XPATH,'//*[@id="popluarGK"]/ul/li[2]/a').click()

# %%
from bs4 import BeautifulSoup
import requests

# %%
table = driver.find_element(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[3]/table/tbody')

# %%
soup = BeautifulSoup(table.get_attribute('outerHTML'), "html.parser")
soup
# Out:
# <tbody>
# <tr style="height: 53px;">
# <th style="width: 66px; height: 53px;" valign="top"> <p><strong>S.N.</strong></p> </th>
# <th style="width: 150px; height: 53px;" valign="top"> <p><strong>PM Name</strong></p> </th>
# <th style="width: 105px; height: 53px;" valign="top"> <p><strong>Born-Dead</strong></p> </th>
# <th style="width: 256px; height: 53px;" valign="top"> <p><strong>Term of office</strong></p> </th>
# <th style="width: 145px; height: 53px;" valign="top"> <p><strong>Remark </strong></p> </th>
# </tr>
# <tr style="height: 121px;">
# <td style="width: 66px; height: 121px;" valign="top"> <p><strong>1. </strong></p> </td>
# <td style="width: 150px; height: 121px;" valign="top"> <p><strong><a href="https://www.jagranjosh.com/general-knowledge/jawaharlal-nehru-biography-1573652876-1" rel="noopener noreferrer nofollow" target="_blank">Jawahar Lal Nehru</a></strong></p> </td>
# <td style="width: 105px; height: 121px;" valign="top"> <p>(1889–1964)</p> </td>
# ...

# %%
table_headers = []
for th in soup.find_all('th'):
    table_headers.append(th.text)

table_data = []
for row in soup.find_all('tr'):
    columns = row.find_all('td')
    output_row = []
    for column in columns:
        output_row.append(column.text)
    table_data.append(output_row)

# %%
df = pd.DataFrame(table_data, columns=table_headers)
df
# Out:
#      S.N.                        PM Name       Born-Dead   \
# 0     None                           None            None
# 1     1.               Jawahar Lal Nehru     (1889–1964)
# 2     2.       Gulzarilal Nanda (Acting)     (1898-1998)
# 3     3.             Lal Bahadur Shastri     (1904–1966)
# 4     4.     Gulzari Lal Nanda  (Acting)     (1898-1998)
# 5     5.                   Indira Gandhi     (1917–1984)
# 6     6.                   Morarji Desai     (1896–1995)
# 7     7.                    Charan Singh     (1902–1987)
# 8      8.                  Indira Gandhi     (1917–1984)
# 9     9.                    Rajiv Gandhi     (1944–1991)
# 10   10.                     V. P. Singh     (1931–2008)
# 11   11.                 Chandra Shekhar     (1927–2007)
# 12   12.             P. V. Narasimha Rao     (1921–2004)
# 13    13.           Atal Bihari Vajpayee    (1924- 2018)
# 14    14.               H. D. Deve Gowda     (born 1933)
# ...
