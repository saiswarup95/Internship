# %% [markdown]
# # Student Grades Prediction Project

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Importing all the necessary libraries here.

# %%
df = pd.read_csv("Grades.csv")
df
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 0       B-  ...     C-     C-     C-     C-     A-      A     C-      B
# 1       D+  ...     D+      D      C      D     A-     B-      C      C
# 2       A-  ...      B      B      A      C      A      A      A     A-
# 3        D  ...     D+      C     D+     C-     B-      B     C+     C+
# 4        A  ...     B-     B+     B+     B-     A-      A     A-     A-
# ..     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 566     A+  ...     A-     A-      A      A      A     B+     B+      B
# 567      A  ...     B+     B+      A      A     A-      B     A-      C
# 568      A  ...     A-      B      A     B+      A      C     B+     A-
# 569     B-  ...      D      B      B     C-      D      C      B     B-
# 570      C  ...     C+      C     B-      D      F     C-     B+      D
#
#     CS-412   CGPA
# 0       A-  2.205
# 1        B  2.008
# 2        A  3.608
# 3       C+  1.906
# 4        A  3.448
# ..     ...    ...
# 566      A  3.798
# 567     A-  3.772
# 568     A-  3.470
# 569      C  2.193
# 570     C-  1.753
#
# [571 rows x 43 columns]

# %% [markdown]
# All the data are loaded through csv file.

# %%
df.head()
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
#
# [5 rows x 43 columns]

# %% [markdown]
# The head() method returns a specified number of rows, string from the top.

# %% [markdown]
# ## Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
#  19  CS-214     565 non-null    object
#  20  EE-217     565 non-null    object
#  21  CS-212     565 non-null    object
#  22  CS-215     565 non-null    object
#  23  MT-331     562 non-null    object
#  24  EF-303     561 non-null    object
#  25  HS-304     561 non-null    object
#  26  CS-301     561 non-null    object
#  27  CS-302     561 non-null    object
#  28  TC-383     561 non-null    object
#  29  MT-442     561 non-null    object
#  30  EL-332     562 non-null    object
#  31  CS-318     562 non-null    object
#  32  CS-306     562 non-null    object
#  33  CS-312     561 non-null    object
#  34  CS-317     559 non-null    object
#  35  CS-403     559 non-null    object
#  36  CS-421     559 non-null    object
#  37  CS-406     486 non-null    object
#  38  CS-414     558 non-null    object
#  39  CS-419     558 non-null    object
#  40  CS-423     557 non-null    object
#  41  CS-412     492 non-null    object
#  42  CGPA       571 non-null    float64
# dtypes: float64(1), object(42)
# memory usage: 191.9+ KB

# %% [markdown]
# Here the info function shows us the column names and the data types.Based on the results from info, we see that there are no null values in the data

# %%
df.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# This function takes a scalar or array-like object and indicates whether values are missing. As we can see, there are some missing values in the dataset.

# %%
df.isnull().sum().sum()
# Out:
# 425

# %% [markdown]
# The function dataframe. isnull(). sum(). sum() returns the number of missing values in the dataset.

# %% [markdown]
# ## Cleaning The Data

# %%
# Check if there is any missing value

sns.heatmap(df.isnull(), cmap='viridis')
plt.show()

# %% [markdown]
# The heatmap() function takes a data matrix as input and plots that matrix as a heatmap. Each cell in the heatmap corresponds to a data point in the matrix, and the color of the cell represents the value of that data point.

# %%
df.replace(np.nan,0, inplace = True)
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# 0  ...     C-     C-     C-     C-     A-      A     C-      B     A-  2.205
# 1  ...     D+      D      C      D     A-     B-      C      C      B  2.008
# 2  ...      B      B      A      C      A      A      A     A-      A  3.608
# 3  ...     D+      C     D+     C-     B-      B     C+     C+     C+  1.906
# 4  ...     B-     B+     B+     B-     A-      A     A-     A-      A  3.448
# 5  ...      C     B-     C+     C+     A-     A-     B+     B-      B  3.026
# 6  ...     B-      C     B+     B-      A     A-     B+     B+      A  2.957
# 7  ...     D+     B+     B+      C      A     B+     A-     A-     A-  3.043
# 8  ...     B+      B     B-     C+      A     A-     B+     A-      A  3.358
# 9  ...     C+     B-     B+     B-      A      A     A-      B      A  3.247
#
# [10 rows x 43 columns]

# %% [markdown]
# Replacing NaN values with zeros.

# %%
input = df.drop(["CS-403","CS-421","CS-406","CS-414","CS-419","CS-423","CS-412", 'MT-442',"Seat No.","CGPA"], axis=1)
target = df[["CGPA"]]

# %%
target.head()
# Out:
#     CGPA
# 0  2.205
# 1  2.008
# 2  3.608
# 3  1.906
# 4  3.448

# %% [markdown]
# The drop() method removes the specified row or column. By specifying the column axis ( axis='columns' ), the drop() method removes the specified column.

# %%
pd.unique(df["PH-121"])
# Out:
# array(['B-', 'A', 'D', 'A-', 'B+', 'B', 'C+', 'C', 'C-', 'D+', 'WU', 'A+',
#        'F'], dtype=object)

# %% [markdown]
# The unique() function finds the unique elements of an array and returns these unique elements as a sorted array.

# %%
grades_enc = {'B-':2.7, 'A':4, 'D':1.0, 'A-':3.7, 'B+':3.4, 'B':3.0, 'C+':2.4, 'C':2.0, 'C-':1.7, 'D+':1.4, 'WU':0.0, 'A+':4,'F':0.0,'W':0,'I':0}

# %%
type(input)
# Out:
# pandas.core.frame.DataFrame

# %%
for item in input:
      input[item] = input[item].replace(grades_enc)

input.head()
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0     2.7     1.4     1.7        2.0     1.7     1.4     1.0     1.7     2.7
# 1     4.0     1.0     1.4        1.0     2.7     2.0     1.0     4.0     1.4
# 2     4.0     3.0     4.0        2.7     3.4     4.0     2.7     3.4     3.7
# 3     1.0     2.4     1.4        1.0     1.0     3.7     1.4     1.7     1.0
# 4     3.7     3.7     3.7        3.4     4.0     4.0     3.7     3.4     4.0
#
#    ME-107  ...  EF-303  HS-304  CS-301  CS-302  TC-383  EL-332  CS-318  \
# 0     1.7  ...     1.7     2.4     3.0     2.0     2.4     2.0     1.7
# 1     1.0  ...     1.0     1.7     3.7     1.4     1.7     2.0     3.7
# 2     3.7  ...     2.4     4.0     3.4     3.7     3.0     3.4     3.7
# 3     2.4  ...     1.0     2.7     1.0     2.7     1.4     1.4     3.4
# 4     3.7  ...     1.7     3.7     2.7     3.7     2.4     3.7     2.7
#
#    CS-306  CS-312  CS-317
# 0     2.0     1.7     1.7
# 1     1.0     1.4     1.0
# 2     3.7     3.0     3.0
# 3     1.7     1.4     2.0
# 4     3.7     2.7     3.4
#
# [5 rows x 33 columns]

# %%
# Concating inputs and targets for data insights
df = pd.concat([input, target], axis=1)

# %% [markdown]
# The pandas. concat() function does all the heavy lifting of performing concatenation operations along with an axis of Pandas objects while performing optional set logic of the indexes on the other axes.

# %% [markdown]
# ## Discover and Visualize the Data to Gain Insights:

# %%
df.hist(bins=30,figsize=(30,15))
plt.show()

# %% [markdown]
# ## Looking for Correlations

# %%
# Looking for correlations
plt.figure(figsize=(15,15))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#            PH-121      HS-101      CY-105   HS-105/12      MT-111      CS-105  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     3.018389    2.628371    3.262697    2.878984    2.988091    3.329247
# std      0.971594    0.908402    0.932997    1.019208    0.954343    0.799826
# min      0.000000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.400000    2.000000    2.700000    2.000000    2.400000    3.000000
# 50%      3.400000    2.700000    3.700000    3.000000    3.400000    3.700000
# 75%      3.700000    3.400000    4.000000    3.700000    3.700000    4.000000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#            CS-106      EL-102      EE-119      ME-107  ...      HS-304  \
# count  571.000000  571.000000  571.000000  571.000000  ...  571.000000
# mean     2.961996    2.969877    3.020140    2.698599  ...    2.761646
# std      0.869226    0.981676    0.839463    1.029323  ...    0.955712
# min      0.000000    0.000000    0.000000    0.000000  ...    0.000000
# 25%      2.400000    2.400000    2.400000    1.700000  ...    2.000000
# 50%      3.000000    3.400000    3.400000    2.700000  ...    3.000000
# 75%      3.700000    3.700000    3.700000    3.700000  ...    3.700000
# max      4.000000    4.000000    4.000000    4.000000  ...    4.000000
#
#            CS-301      CS-302      TC-383      EL-332      CS-318      CS-306  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean     2.850788    3.050088    2.873730    2.863748    2.628371    2.892119
# std      0.970483    0.877124    1.017053    1.009585    1.035205    0.989909
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    2.700000    2.000000    2.000000    2.000000    2.400000
# 50%      3.000000    3.400000    3.000000    3.000000    2.700000    3.000000
# 75%      3.700000    3.700000    3.700000    3.700000    3.400000    3.700000
# max      4.000000    4.000000    4.000000    4.000000    4.000000    4.000000
#
#            CS-312      CS-317        CGPA
# count  571.000000  571.000000  571.000000
# mean     2.892294    2.651138    2.954888
# std      1.095450    0.952455    0.620552
# min      0.000000    0.000000    0.800000
# 25%      2.000000    2.000000    2.538000
# 50%      3.000000    2.700000    3.029000
# 75%      4.000000    3.400000    3.451000
# max      4.000000    4.000000    3.985000
#
# [8 rows x 34 columns]

# %% [markdown]
# The describe() method returns description of the data in the DataFrame. If the DataFrame contains numerical data, the description contains these information for each column: count - The number of not-empty values. mean - The average value.

# %%
df.to_csv('cleaned_data.csv')

# %% [markdown]
# Pandas DataFrame to_csv() function converts DataFrame into CSV data.

# %%
# Splitting file into different columns based on our model prediction requirement
model1_columns = []
model2_columns = []
model3_columns = []
model4_columns = []
for item in [input]:
 for i in item:
   if i[4]=='1':
    model1_columns.append(i)
   elif i[4]=='2':
    model2_columns.append(i)
   elif i[4]=='3':
    model3_columns.append(i)
   else:
    model4_columns.append(i)

model2_columns = model1_columns + model2_columns
model3_columns = model2_columns + model3_columns
model4_columns = model3_columns + model4_columns

# %% [markdown]
# ## Prepare the data for Linear Regression:

# %% [markdown]
# ### Model 1: Predict final CGPA based on GPs of first year only.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model1_columns)].values

# %%
# Split data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.30)

# %%
# Build a Model

from sklearn import linear_model

# Bulid a new Model
lr_1 = linear_model.LinearRegression()

# Train the Model
lr_1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict


# Predict for training set
y_train_predict = lr_1.predict(X_train)

# Predict for training set
y_test_predict = lr_1.predict(X_test)

# %%
input_lr=[]
input_lr.append([4, 3.0, 0, 0, 0, 1.0, 4, 2.0, 0, 4, 4])
print(input_lr )
print(lr_1.predict(input_lr ))
# Out:
# [[4, 3.0, 0, 0, 0, 1.0, 4, 2.0, 0, 4, 4]]
# [2.45527437]

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error


# model evaluation for training set
mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))
print("---------------------------------------")

# model evaluation for testing set
mse_test = mean_squared_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
mae_test = mean_absolute_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("---------------------------------------")
test_score= lr_1.score(X_test, y_test)# Return R2 score . The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse) 
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.1802190118000535
# MAE is 0.12268543064084747
# ---------------------------------------
# The model performance for testing set
# RMSE is 0.17333389637751107
# MAE is 0.11662898859583047
# ---------------------------------------
# The score of model for testing set
# Test score 0.91

# %%
compare={"Actual": y_test, "Predict": y_test_predict}
pd.DataFrame(compare)
# Out:
#      Actual   Predict
# 0     3.335  3.295199
# 1     3.247  3.206729
# 2     3.485  3.463379
# 3     3.253  3.137008
# 4     2.938  2.989902
# ..      ...       ...
# 167   3.949  3.854421
# 168   3.490  3.524706
# 169   2.087  2.011260
# 170   3.737  3.619248
# 171   3.026  3.054347
#
# [172 rows x 2 columns]

# %%
# Visualize the Result
idx= np.random.choice(X_test.shape[0])
print ("Predicted CGPA :", y_test_predict[idx])
print ("Actual CGPA :", y_test[idx])
# Out:
# Predicted CGPA : 3.410903475592021
# Actual CGPA : 3.432

# %%
# visualization
plt.scatter(y_test, y_test_predict,  color='black')
plt.scatter(y_test[idx], y_test_predict[idx])
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA)')
plt.plot([df["CGPA"].min(), df["CGPA"].max()], [df["CGPA"].min(), df["CGPA"].max()], color='red')
plt.show()

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test, y_test_predict,  color='blue')
plt.scatter(y_train, y_train_predict,  color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %% [markdown]
# ### Model 2: Predict final CGPA based on GPs of first two years.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model2_columns)].values

# %%
# Split data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.30)

# %%
# Build a Model

from sklearn import linear_model

# Bulid a new Model
lr_2 = linear_model.LinearRegression()

# Train the Model
lr_2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict


# Predict for training set
y_train_predict = lr_2.predict(X_train)

# Predict for training set
y_test_predict = lr_2.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error


# model evaluation for training set
mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))
print("---------------------------------------")

# model evaluation for testing set
mse_test = mean_squared_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
mae_test = mean_absolute_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("---------------------------------------")
test_score= lr_2.score(X_test, y_test)# Return R2 score . The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse) 
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.17256471893686018
# MAE is 0.11553934693530357
# ---------------------------------------
# The model performance for testing set
# RMSE is 0.17148334858328648
# MAE is 0.11041895193655794
# ---------------------------------------
# The score of model for testing set
# Test score 0.92

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test, y_test_predict,  color='blue')
plt.scatter(y_train, y_train_predict,  color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %% [markdown]
# ### Model 3: Predict final CGPA based on GPs of first three years.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model3_columns)].values

# %%
# Split data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.30)

# %%
# Build a Model

from sklearn import linear_model

# Bulid a new Model
lr_3 = linear_model.LinearRegression()

# Train the Model
lr_3.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict


# Predict for training set
y_train_predict = lr_3.predict(X_train)

# Predict for training set
y_test_predict = lr_3.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error


# model evaluation for training set
mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))
print("---------------------------------------")

# model evaluation for testing set
mse_test = mean_squared_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
mae_test = mean_absolute_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("---------------------------------------")
test_score= lr_3.score(X_test, y_test)# Return R2 score . The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse) 
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.16367605259420015
# MAE is 0.11035222850043838
# ---------------------------------------
# The model performance for testing set
# RMSE is 0.16928576125138714
# MAE is 0.1037853350567408
# ---------------------------------------
# The score of model for testing set
# Test score 0.92

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test, y_test_predict,  color='blue')
plt.scatter(y_train, y_train_predict,  color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %% [markdown]
# ### Model 4: Predict final CGPA based on GPs of first four years.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model4_columns)].values

# %%
# Split data

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.30)

# %%
# Build a Model

from sklearn import linear_model

# Bulid a new Model
lr_4 = linear_model.LinearRegression()

# Train the Model
lr_4.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict


# Predict for training set
y_train_predict = lr_4.predict(X_train)

# Predict for training set
y_test_predict = lr_4.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error , mean_absolute_error


# model evaluation for training set
mse_train = mean_squared_error(y_train, y_train_predict)
mae_train = mean_absolute_error(y_train, y_train_predict)
print("The model performance for training set")
print('RMSE is {}'.format(np.sqrt(mse_train)))
print('MAE is {}'.format(mae_train))
print("---------------------------------------")

# model evaluation for testing set
mse_test = mean_squared_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
mae_test = mean_absolute_error(y_test, y_test_predict) # Return the loss it is non-negative . The best value is 0.0
print("The model performance for testing set")
print('RMSE is {}'.format(np.sqrt(mse_test)))
print('MAE is {}'.format(mae_test))

print("---------------------------------------")
test_score= lr_4.score(X_test, y_test)# Return R2 score . The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse) 
print("The score of model for testing set")
print('Test score {}'.format(test_score.round(2)))
# Out:
# The model performance for training set
# RMSE is 0.14786303037420415
# MAE is 0.09408093104532622
# ---------------------------------------
# The model performance for testing set
# RMSE is 0.12012894032404761
# MAE is 0.09366492910045075
# ---------------------------------------
# The score of model for testing set
# Test score 0.96

# %%
plt.figure(figsize=(22,5))
plt.scatter(y_test, y_test_predict,  color='blue')
plt.scatter(y_train, y_train_predict,  color='Orange')
plt.plot([df['CGPA'].min(), df['CGPA'].max()], [df['CGPA'].min(), df['CGPA'].max()], color='red')
plt.xlabel('CGPA')
plt.ylabel('Predicted CGPA')
plt.show()

# %% [markdown]
# ## Prepare the data for Random Forest:

# %% [markdown]
# ### Model 1: Predict final CGPA based on GPs of first year only.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model1_columns)].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_1 = RandomForestRegressor(n_estimators=20, random_state=0)
rf_1.fit(X_train, y_train)
y_pred = rf_1.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("The score of model for testing set",rf_1.score(X_test, y_test))
# Out:
# Mean Absolute Error: 0.10921650879917184
# Mean Squared Error: 0.020554085556170734
# Root Mean Squared Error: 0.1433669611736635
# The score of model for testing set 0.9408973347528843

# %% [markdown]
# ### Model 2: Predict final CGPA based on GPs of first two years.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model2_columns)].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_2 = RandomForestRegressor(n_estimators=20, random_state=0)
rf_2.fit(X_train, y_train)
y_pred = rf_2.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("The score of model for testing set",rf_2.score(X_test, y_test))
# Out:
# Mean Absolute Error: 0.10959565217391298
# Mean Squared Error: 0.02154312491304347
# Root Mean Squared Error: 0.14677576405198328
# The score of model for testing set 0.9380533813273852

# %% [markdown]
# ### Model 3: Predict final CGPA based on GPs of first three years.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model3_columns)].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_3 = RandomForestRegressor(n_estimators=20, random_state=0)
rf_3.fit(X_train, y_train)
y_pred = rf_3.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("The score of model for testing set",rf_3.score(X_test, y_test))
# Out:
# Mean Absolute Error: 0.10514521739130435
# Mean Squared Error: 0.019085767217391306
# Root Mean Squared Error: 0.1381512476143133
# The score of model for testing set 0.9451194407189183

# %% [markdown]
# ### Model 4: Predict final CGPA based on GPs of first four years.

# %%
# Input data
labels = df['CGPA'].values
features = df[list(model4_columns)].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

rf_4 = RandomForestRegressor(n_estimators=20, random_state=0)
rf_4.fit(X_train, y_train)
y_pred = rf_4.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("The score of model for testing set",rf_4.score(X_test, y_test))
# Out:
# Mean Absolute Error: 0.09541086956521737
# Mean Squared Error: 0.015856359760869566
# Root Mean Squared Error: 0.12592203842405653
# The score of model for testing set 0.9544055063688709
